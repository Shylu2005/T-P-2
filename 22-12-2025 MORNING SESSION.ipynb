# %% [markdown]
# <a href="https://colab.research.google.com/github/Shylu2005/T-P-2/blob/main/22-12-2025%20MORNING%20SESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DSA array
arr=[]
arr.append(10)
arr.append(20)
arr.append(30)
arr.append(40)
#Traverse
for i in arr:
  print(i)
#search
find=10
for i in range(len(arr)):
  if arr[i]==find:
    print("find element in:",i,"index")
    break
  else:
    print("No element found")
#add elements in between
arr.insert(0,500)
print(arr)
print(arr[0])
arr.remove(20)
print(arr)
# Out:
# 10
# 20
# 30
# 40
# find element in: 0 index
# [500, 10, 20, 30, 40]
# 500
# [500, 10, 30, 40]

# %%
#Linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
    def addFirst(self, data):
        newNode = Node(data)
        newNode.next = self.head
        self.head = newNode

    def addLast(self,data):
        newNode=Node(data)
        if self.head is None:
            self.head=newNode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newNode
    def printNodes(self):
        temp=self.head
        while(temp):
            print(temp.data,end="->")
            temp=temp.next
        print("None")
    def len(self):
      if self.head is None:
        print("There are no elements")
        temp=self.head
        count=0
        while(temp):
            count+=1
            temp=temp.next
        return count
l1=LinkedList()
l1.addFirst(10)
l1.addLast(100)
l1.addFirst(20)
l1.printNodes()
print(l1.len())
# Out:
# 20->10->100->None
# None

# %%
#Linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
    def addFirst(self, data):
        newNode = Node(data)
        newNode.next = self.head
        self.head = newNode

    def addLast(self,data):
        newNode=Node(data)
        if self.head is None:
            self.head=newNode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newNode
    def printNodes(self):
        temp=self.head
        while(temp):
            print(temp.data,end="->")
            temp=temp.next
        print("None")
    def len(self):
      if self.head is None:
        print("There are no elements")
        temp=self.head
        count=0
        while(temp):
            count+=1
            temp=temp.next
        return count
l1=LinkedList()
l1.printNodes()
print(l1.len())
# Out:
# None
# There are no elements
# 0
