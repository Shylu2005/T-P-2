# %% [markdown]
# <a href="https://colab.research.google.com/github/Shylu2005/T-P-2/blob/main/15-12-2025%20EVENING%20SESSIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Evening session
student={
    "id":100,
    "name":"raj",
    "age":20,
    "id":200
}
student["dep"]="cse"
student["dep"]="ece"
print(student["age"])
print(student.get("age"))
for k in student:
  print(k)
for k in student.values():
  print(k)
print(student)
# Out:
# 20
# 20
# id
# name
# age
# dep
# 200
# raj
# 20
# ece
# {'id': 200, 'name': 'raj', 'age': 20, 'dep': 'ece'}
